# %%
from jupyterthemes import jtplot
jtplot.style(theme = 'monokai', context = 'notebook', ticks = True, grid = False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
company_stock = pd.read_csv ('stock_data.csv')
company_stock
# Out:
#             Date          FB       TWTR        NFLX
# 0     2013-11-07   47.560001  44.900002   46.694286
# 1     2013-11-08   47.529999  41.650002   47.842857
# 2     2013-11-11   46.200001  42.900002   48.272858
# 3     2013-11-12   46.610001  41.900002   47.675713
# 4     2013-11-13   48.709999  42.599998   47.897144
# ...          ...         ...        ...         ...
# 1707  2020-08-20  269.010010  38.959999  497.899994
# 1708  2020-08-21  267.010010  39.259998  492.309998
# 1709  2020-08-24  271.390015  40.490002  488.809998
# 1710  2020-08-25  280.820007  40.549999  490.579987
# 1711  2020-08-26  303.910004  41.080002  547.530029
#
# [1712 rows x 4 columns]

# %%
company_stock.plot (x = 'Date', y = 'TWTR', label = 'Twitter Stock Price', figsize = (15,15), linewidth = (1), color = 'white')
plt.title ('Twitter Stock')
plt.legend (loc = 'upper left')
plt.xlabel ('Date')
plt.ylabel ('Price [$]')
plt.grid()

# %%
daily_return = pd.read_csv ('stocks_daily_returns.csv')
daily_return
# Out:
#             Date        FB      TWTR       NFLX
# 0     2013-11-07  0.000000  0.000000   0.000000
# 1     2013-11-08 -0.063082 -7.238307   2.459768
# 2     2013-11-11 -2.798229  3.001200   0.898778
# 3     2013-11-12  0.887446 -2.331002  -1.237020
# 4     2013-11-13  4.505467  1.670635   0.464452
# ...          ...       ...       ...        ...
# 1707  2020-08-20  2.444881  0.179995   2.759374
# 1708  2020-08-21 -0.743467  0.770018  -1.122715
# 1709  2020-08-24  1.640390  3.132970  -0.710934
# 1710  2020-08-25  3.474701  0.148177   0.362102
# 1711  2020-08-26  8.222348  1.307036  11.608717
#
# [1712 rows x 4 columns]

# %%
daily_return.plot (x = 'Date', y = 'TWTR', label = 'Stocks Daily Returns', figsize = (15,15), linewidth = (1), color = 'white')
plt.grid()
plt.title ('Twitter Stocks Daily  Return')
plt.legend (loc = 'upper left')
plt.xlabel ('Date')
plt.ylabel ('Price [$]')
# Out:
# Text(0, 0.5, 'Price [$]')

# %%
daily_return.plot (x = 'Date', y = 'NFLX', label = 'Stocks Daily Returns', figsize = (15,15), linewidth = (1), color = 'white')
plt.grid()
plt.title ('Netflix Stocks Daily  Return')
plt.legend (loc = 'upper left')
plt.xlabel ('Date')
plt.ylabel ('Price [$]')
# Out:
# Text(0, 0.5, 'Price [$]')

# %%
x_value = daily_return ['TWTR']
x_value
# Out:
# 0       0.000000
# 1      -7.238307
# 2       3.001200
# 3      -2.331002
# 4       1.670635
#           ...
# 1707    0.179995
# 1708    0.770018
# 1709    3.132970
# 1710    0.148177
# 1711    1.307036
# Name: TWTR, Length: 1712, dtype: float64

# %%
y_value = daily_return ['NFLX']
y_value
# Out:
# 0        0.000000
# 1        2.459768
# 2        0.898778
# 3       -1.237020
# 4        0.464452
#           ...
# 1707     2.759374
# 1708    -1.122715
# 1709    -0.710934
# 1710     0.362102
# 1711    11.608717
# Name: NFLX, Length: 1712, dtype: float64

# %%
plt.figure (figsize=(15,15))
plt.grid()
plt.scatter (x_value, y_value)
